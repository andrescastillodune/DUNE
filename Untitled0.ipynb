# %% [markdown]
# <a href="https://colab.research.google.com/github/andrescastillodune/DUNE/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import astropy.units as u
from astropy.coordinates import SkyCoord
from matplotlib import pyplot as plt
from matplotlib import rc
import matplotlib.ticker as mticker
from mpl_toolkits import mplot3d
import numpy as np
from astropy.coordinates import Angle

rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
rc('text', usetex=True)
rc('font', weight='bold')

paramsd = {'legend.fontsize': 18,
           'legend.handlelength': 2, 'figure.figsize': (14, 8)}
plt.rcParams.update(paramsd)

# %%
#Aquí para cada pulsar se tiene que poner las coordenadas en right ascension y declination en grados y la distancia a la tierra en parsecs
#y nos transforma a coordenadas galactocéntricas x y z, con esto más abajo calculamos la distancia al centro galáctico.
# COORDINATES AND DISTANCE OF EARTH
gcEARTH = SkyCoord(ra=0*u.degree, dec=0*u.degree,
                   distance=0*u.parsec, frame='icrs')
# print('EARTH:  ', gcEARTH.transform_to('galactocentric'))
XEARTH = gcEARTH.transform_to('galactocentric').x.value
YEARTH = gcEARTH.transform_to('galactocentric').y.value
ZEARTH = gcEARTH.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J0437-4715
gcJ0437 = SkyCoord(ra=69.3159*u.degree, dec=-47.2524 *
                   u.degree, distance=157.6*u.parsec, frame='icrs')
# print('J0437-4715:  ', gcJ0437.transform_to('galactocentric'))
XJ0437 = gcJ0437.transform_to('galactocentric').x.value
YJ0437 = gcJ0437.transform_to('galactocentric').y.value
ZJ0437 = gcJ0437.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF CRAB
gcCRAB = SkyCoord(ra=83.6332*u.degree, dec=22.0145*u.degree,
                  distance=2500*u.parsec, frame='icrs')
# print('CRAB:  ', gcCRAB.transform_to('galactocentric'))
XCRAB = gcCRAB.transform_to('galactocentric').x.value
YCRAB = gcCRAB.transform_to('galactocentric').y.value
ZCRAB = gcCRAB.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J0613-0200
gcJ0613 = SkyCoord(ra=93.4332*u.degree, dec=-2.01312 *
                   u.degree, distance=1090*u.parsec, frame='icrs')
# print('J0613-0200:  ', gcJ0613.transform_to('galactocentric'))
XJ0613 = gcJ0613.transform_to('galactocentric').x.value
YJ0613 = gcJ0613.transform_to('galactocentric').y.value
ZJ0613 = gcJ0613.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J0711-6830
gcJ0711 = SkyCoord(ra=107.976*u.degree, dec=-68.5132 *
                   u.degree, distance=154*u.parsec, frame='icrs')
# print('J0711-6830:  ', gcJ0711.transform_to('galactocentric'))
XJ0711 = gcJ0711.transform_to('galactocentric').x.value
YJ0711 = gcJ0711.transform_to('galactocentric').y.value
ZJ0711 = gcJ0711.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1022+1001
gcJ1022 = SkyCoord(ra=155.742*u.degree, dec=10.0313*u.degree,
                   distance=740*u.parsec, frame='icrs')
# print('J1022+1001:  ', gcJ1022.transform_to('galactocentric'))
XJ1022 = gcJ1022.transform_to('galactocentric').x.value
YJ1022 = gcJ1022.transform_to('galactocentric').y.value
ZJ1022 = gcJ1022.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1024-0719
gcJ1024 = SkyCoord(ra=156.161*u.degree, dec=-7.32209 *
                   u.degree, distance=1500*u.parsec, frame='icrs')
# print('J1024-0719:  ', gcJ1024.transform_to('galactocentric'))
XJ1024 = gcJ1024.transform_to('galactocentric').x.value
YJ1024 = gcJ1024.transform_to('galactocentric').y.value
ZJ1024 = gcJ1024.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1045-4509
gcJ1045 = SkyCoord(ra=161.459*u.degree, dec=-45.165*u.degree,
                   distance=1090*u.parsec, frame='icrs')
# print('J1045-4509:  ', gcJ1045.transform_to('galactocentric'))
XJ1045 = gcJ1045.transform_to('galactocentric').x.value
YJ1045 = gcJ1045.transform_to('galactocentric').y.value
ZJ1045 = gcJ1045.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1600-3053
gcJ1600 = SkyCoord(ra=240.216*u.degree, dec=-436.544/15 *
                   u.degree, distance=2170*u.parsec, frame='icrs')
# print('J1600-3053:  ', gcJ1600.transform_to('galactocentric'))
XJ1600 = gcJ1600.transform_to('galactocentric').x.value
YJ1600 = gcJ1600.transform_to('galactocentric').y.value
ZJ1600 = gcJ1600.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1603-7202
gcJ1603 = SkyCoord(ra=240.899*u.degree, dec=-72.0424313 *
                   u.degree, distance=3900*u.parsec, frame='icrs')
# print('J1603-7202:  ', gcJ1603.transform_to('galactocentric'))
XJ1603 = gcJ1603.transform_to('galactocentric').x.value
YJ1603 = gcJ1603.transform_to('galactocentric').y.value
ZJ1603 = gcJ1603.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1643-1224
gcJ1643 = SkyCoord(ra=250.909*u.degree, dec=-12.4163 *
                   u.degree, distance=1600*u.parsec, frame='icrs')
# print('J1643-1224:  ', gcJ1643.transform_to('galactocentric'))
XJ1643 = gcJ1643.transform_to('galactocentric').x.value
YJ1643 = gcJ1643.transform_to('galactocentric').y.value
ZJ1643 = gcJ1643.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1713+0747
gcJ1713 = SkyCoord(ra=258.456*u.degree, dec=7.79375*u.degree,
                   distance=1350*u.parsec, frame='icrs')
# print('J1713+0747:  ', gcJ1713.transform_to('galactocentric'))
XJ1713 = gcJ1713.transform_to('galactocentric').x.value
YJ1713 = gcJ1713.transform_to('galactocentric').y.value
ZJ1713 = gcJ1713.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1730-2304
gcJ1730 = SkyCoord(ra=262.59*u.degree, dec=-23.0711*u.degree,
                   distance=500*u.parsec, frame='icrs')
# print('J1730-2304:  ', gcJ1730.transform_to('galactocentric'))
XJ1730 = gcJ1730.transform_to('galactocentric').x.value
YJ1730 = gcJ1730.transform_to('galactocentric').y.value
ZJ1730 = gcJ1730.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1732-5049
gcJ1732 = SkyCoord(ra=263.2*u.degree, dec=-50.8156*u.degree,
                   distance=1875*u.parsec, frame='icrs')
# print('J17332-5049:  ', gcJ1732.transform_to('galactocentric'))
XJ1732 = gcJ1732.transform_to('galactocentric').x.value
YJ1732 = gcJ1732.transform_to('galactocentric').y.value
ZJ1732 = gcJ1732.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1744-1134
gcJ1744 = SkyCoord(ra=266.123*u.degree, dec=-11.5819 *
                   u.degree, distance=419*u.parsec, frame='icrs')
# print('J1744-1134:  ', gcJ1744.transform_to('galactocentric'))
XJ1744 = gcJ1744.transform_to('galactocentric').x.value
YJ1744 = gcJ1744.transform_to('galactocentric').y.value
ZJ1744 = gcJ1744.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1824-2452
gcJ1824 = SkyCoord(ra=276.131*u.degree, dec=-24.8721 *
                   u.degree, distance=5500*u.parsec, frame='icrs')
# print('J1824-2452:  ', gcJ1824.transform_to('galactocentric'))
XJ1824 = gcJ1824.transform_to('galactocentric').x.value
YJ1824 = gcJ1824.transform_to('galactocentric').y.value
ZJ1824 = gcJ1824.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1857+0943
gcJ1857 = SkyCoord(ra=284.402*u.degree, dec=-9.72144 *
                   u.degree, distance=1480*u.parsec, frame='icrs')
# print('J1857+0943:  ', gcJ1857.transform_to('galactocentric'))
XJ1857 = gcJ1857.transform_to('galactocentric').x.value
YJ1857 = gcJ1857.transform_to('galactocentric').y.value
ZJ1857 = gcJ1857.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1909-3744
gcJ1909 = SkyCoord(ra=287.448*u.degree, dec=-37.7374 *
                   u.degree, distance=1171*u.parsec, frame='icrs')
# print('J1909-3744:  ', gcJ1909.transform_to('galactocentric'))
XJ1909 = gcJ1909.transform_to('galactocentric').x.value
YJ1909 = gcJ1909.transform_to('galactocentric').y.value
ZJ1909 = gcJ1909.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1939+2134
gcJ1939 = SkyCoord(ra=294.911*u.degree, dec=21.5831*u.degree,
                   distance=6300*u.parsec, frame='icrs')
# print('J1939+2134:  ', gcJ1939.transform_to('galactocentric'))
XJ1939 = gcJ1939.transform_to('galactocentric').x.value
YJ1939 = gcJ1939.transform_to('galactocentric').y.value
ZJ1939 = gcJ1939.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J2124-3358
gcJ2124 = SkyCoord(ra=321.183*u.degree, dec=-33.9792 *
                   u.degree, distance=490*u.parsec, frame='icrs')
# print('J2124-3358:  ', gcJ2124.transform_to('galactocentric'))
XJ2124 = gcJ2124.transform_to('galactocentric').x.value
YJ2124 = gcJ2124.transform_to('galactocentric').y.value
ZJ2124 = gcJ2124.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J2129-5721
gcJ2129 = SkyCoord(ra=322.345*u.degree, dec=-57.354*u.degree,
                   distance=7400*u.parsec, frame='icrs')
# print('J2129-5721:  ', gcJ2129.transform_to('galactocentric'))
XJ2129 = gcJ2129.transform_to('galactocentric').x.value
YJ2129 = gcJ2129.transform_to('galactocentric').y.value
ZJ2129 = gcJ2129.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J2145-0750
gcJ2145 = SkyCoord(ra=326.46*u.degree, dec=-7.83847*u.degree,
                   distance=760*u.parsec, frame='icrs')
# print('J2145-0750:  ', gcJ2145.transform_to('galactocentric'))
XJ2145 = gcJ2145.transform_to('galactocentric').x.value
YJ2145 = gcJ2145.transform_to('galactocentric').y.value
ZJ2145 = gcJ2145.transform_to('galactocentric').z.value


# COORDINATES AND DISTANCE OF J1745–2900
gcJ1745 = SkyCoord(ra=266.417*u.degree, dec=-29.0083*u.degree,
                   distance=8121*u.parsec, frame='icrs')
# print('J1745–2900:  ', gcJ1745.transform_to('galactocentric'))
XJ1745 = gcJ1745.transform_to('galactocentric').x.value
YJ1745 = gcJ1745.transform_to('galactocentric').y.value
ZJ1745 = gcJ1745.transform_to('galactocentric').z.value

# COORDINATES AND DISTANCE OF J1744−2946.
gcJ1744 = SkyCoord(ra=266.0645917*u.degree, dec=-29.7810139*u.degree,
                   distance=8115*u.parsec, frame='icrs')
# print('J1745–2900:  ', gcgcJ1744.transform_to('galactocentric'))
XgcJ1744 = gcJ1744.transform_to('galactocentric').x.value
YgcJ1744 = gcJ1744.transform_to('galactocentric').y.value
ZgcJ1744 = gcJ1744.transform_to('galactocentric').z.value


# %%

####### GALACTIC 3D PLOT ###########


# ax = plt.axes(projection='3d')
# ax.scatter3D(0, 0, 0, c='black', label='Galactic Center')
# ax.scatter3D(XEARTH, YEARTH, ZEARTH, c='blue', label='Earth')
# ax.scatter3D(XJ0437, YJ0437, ZJ0437, c='red', marker='*', label='J0437')
# ax.scatter3D(XJ1600, YJ1600, ZJ1600, c='green', marker='*', label='J1600')
# ax.scatter3D(XJ1643, YJ1643, ZJ1643, c='cyan', marker='*', label='J1643')
# ax.scatter3D(XJ1713, YJ1713, ZJ1713, c='purple', marker='*', label='J1713')
# ax.scatter3D(XJ1909, YJ1909, ZJ1909, c='violet', marker='*', label='J1909')
# ax.scatter3D(XJ1939, YJ1939, ZJ1939, c='forestgreen',
#              marker='*', label='J1939')
# ax.scatter3D(XJ2129, YJ2129, ZJ2129, c='orange', marker='*', label='J2129')
# ax.scatter3D(XJ1824, YJ1824, ZJ1824, c='mediumslateblue',
#              marker='*', label='J1824')
# ax.legend()

# plt.show()
# %%

# ####### DISTANCE TO GALACTIC CENTER ###########
DEARTH = np.sqrt(XEARTH**2 + YEARTH**2 + ZEARTH**2)
DJ0437 = np.sqrt(XJ0437**2 + YJ0437**2 + ZJ0437**2)
DCRAB = np.sqrt(XCRAB**2 + YCRAB**2 + ZCRAB**2)
DJ0613 = np.sqrt(XJ0613**2 + YJ0613**2 + ZJ0613**2)
DJ0711 = np.sqrt(XJ0711**2 + YJ0711**2 + ZJ0711**2)
DJ1022 = np.sqrt(XJ1022**2 + YJ1022**2 + ZJ1022**2)
DJ1024 = np.sqrt(XJ1024**2 + YJ1024**2 + ZJ1024**2)
DJ1045 = np.sqrt(XJ1045**2 + YJ1045**2 + ZJ1045**2)
DJ1600 = np.sqrt(XJ1600**2 + YJ1600**2 + ZJ1600**2)
DJ1603 = np.sqrt(XJ1603**2 + YJ1603**2 + ZJ1603**2)
DJ1643 = np.sqrt(XJ1643**2 + YJ1643**2 + ZJ1643**2)
DJ1713 = np.sqrt(XJ1713**2 + YJ1713**2 + ZJ1713**2)
DJ1730 = np.sqrt(XJ1730**2 + YJ1730**2 + ZJ1730**2)
DJ1732 = np.sqrt(XJ1732**2 + YJ1732**2 + ZJ1732**2)
DJ1744 = np.sqrt(XJ1744**2 + YJ1744**2 + ZJ1744**2)
DJ1824 = np.sqrt(XJ1824**2 + YJ1824**2 + ZJ1824**2)
DJ1857 = np.sqrt(XJ1857**2 + YJ1857**2 + ZJ1857**2)
DJ1909 = np.sqrt(XJ1909**2 + YJ1909**2 + ZJ1909**2)
DJ1939 = np.sqrt(XJ1939**2 + YJ1939**2 + ZJ1939**2)
DJ2124 = np.sqrt(XJ2124**2 + YJ2124**2 + ZJ2124**2)
DJ2129 = np.sqrt(XJ2129**2 + YJ2129**2 + ZJ2129**2)
DJ2145 = np.sqrt(XJ2145**2 + YJ2145**2 + ZJ2145**2)
DJ1745 = np.sqrt(XJ1745**2 + YJ1745**2 + ZJ1745**2)
DgcJ1744 = np.sqrt(XgcJ1744**2 + YgcJ1744**2 + ZgcJ1744**2)


r = np.linspace(2500, 10500, 250)

#Quizás toca buscar unos parámetros más actualizados
def rhodm(dist):
    rho0 = 0.787  # GeV cm^-3
    Rs = 10940  # parsec
    return rho0/((dist/Rs)*(1+dist/Rs)**2)


print('DEARTH  ',DEARTH)
print('DJ0437  ',rhodm(DJ0437))
print('DCRAB   ',rhodm(DCRAB ))
print('DJ0613  ',rhodm(DJ0613))
print('DJ0711  ',rhodm(DJ0711))
print('DJ1022  ',rhodm(DJ1022))
print('DJ1024  ',rhodm(DJ1024))
print('DJ1045  ',rhodm(DJ1045))
print('DJ1600  ',rhodm(DJ1600))
print('DJ1603  ',rhodm(DJ1603))
print('DJ1643  ',rhodm(DJ1643))
print('DJ1713  ',rhodm(DJ1713))
print('DJ1730  ',rhodm(DJ1730))
print('DJ1732  ',rhodm(DJ1732))
print('DJ1744  ',rhodm(DJ1744))
print('DJ1824  ',rhodm(DJ1824))
print('DJ1857  ',rhodm(DJ1857))
print('DJ1909  ',rhodm(DJ1909))
print('DJ1939  ',rhodm(DJ1939))
print('DJ2124  ',rhodm(DJ2124))
print('DJ2129  ',rhodm(DJ2129))
print('DJ2145  ',rhodm(DJ2145))
print('DJ1745  ',rhodm(DJ1745))
print('DgcJ1744',rhodm(DgcJ1744))


# EPTA

def DA(H,M,S):
    DA = (H + M/60 + S/3600)*15
    return DA

def GA(D,M,S):
    GA = (D+M/60+S/3600)
    return GA

# B1937 # J1939+2134
RAB1937 = DA(19,39,38.561224)
DAB1937 = GA(21,34,59.14166)
DIS1937 = 3266 # pc


gcB1937 = SkyCoord(ra=RAB1937*u.degree, dec=DAB1937 *
                   u.degree, distance=DIS1937*u.parsec, frame='icrs')
# print('JB1937:  ', gcB1937.transform_to('galactocentric'))
XB1937 = gcB1937.transform_to('galactocentric').x.value
YB1937 = gcB1937.transform_to('galactocentric').y.value
ZB1937 = gcB1937.transform_to('galactocentric').z.value

# J0751
RAJ0751 = DA(7,51,9.155331)
DAJ0751 = GA(18,7,38.4864)
DISJ0751 = 999 # pc



gcJ0751 = SkyCoord(ra=RAJ0751*u.degree, dec=DAJ0751 *
                   u.degree, distance=DISJ0751*u.parsec, frame='icrs')
# print('J0751:  ', gcJ0751.transform_to('galactocentric'))
XJ0751 = gcJ0751.transform_to('galactocentric').x.value
YJ0751 = gcJ0751.transform_to('galactocentric').y.value
ZJ0751 = gcJ0751.transform_to('galactocentric').z.value

DJ0751 = np.sqrt(XJ0751**2 + YJ0751**2 + ZJ0751**2)



# J1012
RAJ1012 = DA(10,12,33.437521)
DAJ1012 = GA(53,7,2.29999)
DISJ1012 = 1148 # pc



gcJ1012 = SkyCoord(ra=RAJ1012*u.degree, dec=DAJ1012 *
                   u.degree, distance=DISJ1012*u.parsec, frame='icrs')
# print('J1012:  ', gcJ1012.transform_to('galactocentric'))
XJ1012 = gcJ1012.transform_to('galactocentric').x.value
YJ1012 = gcJ1012.transform_to('galactocentric').y.value
ZJ1012 = gcJ1012.transform_to('galactocentric').z.value

DJ1012 = np.sqrt(XJ1012**2 + YJ1012**2 + ZJ1012**2)


# J1022
RAJ1022 = DA(10,22,57.9992)
DAJ1022 = GA(10,1,52.78)
DISJ1022 = 1092 # pc



gcJ1022 = SkyCoord(ra=RAJ1022*u.degree, dec=DAJ1022 *
                   u.degree, distance=DISJ1022*u.parsec, frame='icrs')
# print('J1022:  ', gcJ1022.transform_to('galactocentric'))
XJ1022 = gcJ1022.transform_to('galactocentric').x.value
YJ1022 = gcJ1022.transform_to('galactocentric').y.value
ZJ1022 = gcJ1022.transform_to('galactocentric').z.value

DJ1022 = np.sqrt(XJ1022**2 + YJ1022**2 + ZJ1022**2)




# J1024
RAJ1024 = DA(10,24,38.675378)
DAJ1024 = GA(-7,19,19.43395)
DISJ1024 = 1083 # pc



gcJ1024 = SkyCoord(ra=RAJ1024*u.degree, dec=DAJ1024 *
                   u.degree, distance=DISJ1024*u.parsec, frame='icrs')
# print('J1024:  ', gcJ1024.transform_to('galactocentric'))
XJ1024 = gcJ1024.transform_to('galactocentric').x.value
YJ1024 = gcJ1024.transform_to('galactocentric').y.value
ZJ1024 = gcJ1024.transform_to('galactocentric').z.value

DJ1024 = np.sqrt(XJ1024**2 + YJ1024**2 + ZJ1024**2)

# J1600-3053
RAJ1600 = DA(16,00,51.903338)
DAJ1600 = GA(-30,53,49.37542)
DISJ1600 = 1492 # pc



gcJ1600 = SkyCoord(ra=RAJ1600*u.degree, dec=DAJ1600 *
                   u.degree, distance=DISJ1600*u.parsec, frame='icrs')
# print('J1600:  ', gcJ1600.transform_to('galactocentric'))
XJ1600 = gcJ1600.transform_to('galactocentric').x.value
YJ1600 = gcJ1600.transform_to('galactocentric').y.value
ZJ1600 = gcJ1600.transform_to('galactocentric').z.value

DJ1600 = np.sqrt(XJ1600**2 + YJ1600**2 + ZJ1600**2)


# J1643-1224
RAJ1643 = DA(16,43,38.161498)
DAJ1643 = GA(-12,24,58.6735)
DISJ1643 =  758 # pc



gcJ1643 = SkyCoord(ra=RAJ1643*u.degree, dec=DAJ1643 *
                   u.degree, distance=DISJ1643*u.parsec, frame='icrs')
# print('J1643:  ', gcJ1643.transform_to('galactocentric'))
XJ1643 = gcJ1643.transform_to('galactocentric').x.value
YJ1643 = gcJ1643.transform_to('galactocentric').y.value
ZJ1643 = gcJ1643.transform_to('galactocentric').z.value

DJ1643 = np.sqrt(XJ1643**2 + YJ1643**2 + ZJ1643**2)



# J1713+0747
RAJ1713 = DA(17,13,49.5331754)
DAJ1713 = GA(7,47,37.492536)
DISJ1713 =  1108 # pc



gcJ1713 = SkyCoord(ra=RAJ1713*u.degree, dec=DAJ1713 *
                   u.degree, distance=DISJ1713*u.parsec, frame='icrs')
# print('J1713:  ', gcJ1713.transform_to('galactocentric'))
XJ1713 = gcJ1713.transform_to('galactocentric').x.value
YJ1713 = gcJ1713.transform_to('galactocentric').y.value
ZJ1713 = gcJ1713.transform_to('galactocentric').z.value

DJ1713 = np.sqrt(XJ1713**2 + YJ1713**2 + ZJ1713**2)







# J1730-2304
RAJ1730 = DA(17,30,21.66835)
DAJ1730 = GA(-23,4,31.16)
DISJ1730 =   904 # pc



gcJ1730 = SkyCoord(ra=RAJ1730*u.degree, dec=DAJ1730 *
                   u.degree, distance=DISJ1730*u.parsec, frame='icrs')
# print('J1713:  ', gcJ1713.transform_to('galactocentric'))
XJ1730 = gcJ1730.transform_to('galactocentric').x.value
YJ1730 = gcJ1730.transform_to('galactocentric').y.value
ZJ1730 = gcJ1730.transform_to('galactocentric').z.value

DJ1730 = np.sqrt(XJ1730**2 + YJ1730**2 + ZJ1730**2)



# J1744-1134
RAJ1744 = DA(17,44,29.4075373)
DAJ1744 = GA(-11,34,54.69437)
DISJ1744 = 419# pc



gcJ1744 = SkyCoord(ra=RAJ1744*u.degree, dec=DAJ1744 *
                   u.degree, distance=DISJ1744*u.parsec, frame='icrs')
# print('J1713:  ', gcJ1713.transform_to('galactocentric'))
XJ1744 = gcJ1744.transform_to('galactocentric').x.value
YJ1744 = gcJ1744.transform_to('galactocentric').y.value
ZJ1744 = gcJ1744.transform_to('galactocentric').z.value

DJ1744 = np.sqrt(XJ1744**2 + YJ1744**2 + ZJ1744**2)




# J1911+1347
RAJ1911 = DA(19,11,49.28233)
DAJ1911= GA(-11,14,22.48)
DISJ1911 = 988# pc  SIN DISTANCIA



gcJ1911= SkyCoord(ra=RAJ1911*u.degree, dec=DAJ1911 *
                   u.degree, distance=DISJ1911*u.parsec, frame='icrs')
# print('J1911:  ', gcJ1911.transform_to('galactocentric'))
XJ1911 = gcJ1911.transform_to('galactocentric').x.value
YJ1911 = gcJ1911.transform_to('galactocentric').y.value
ZJ1911 = gcJ1911.transform_to('galactocentric').z.value

DJ1911 = np.sqrt(XJ1911**2 + YJ1911**2 + ZJ1911**2)



# J2145-0750
RAJ2145 = DA(21,45,50.460593)
DAJ2145 = GA(-7,50,18.4876)
DISJ2145 = 645# pc



gcJ2145 = SkyCoord(ra=RAJ2145*u.degree, dec=DAJ2145 *
                   u.degree, distance=DISJ2145*u.parsec, frame='icrs')
# print('J1911:  ', gcJ1911.transform_to('galactocentric'))
XJ2145 = gcJ2145.transform_to('galactocentric').x.value
YJ2145 = gcJ2145.transform_to('galactocentric').y.value
ZJ2145 = gcJ2145.transform_to('galactocentric').z.value

DJ2145 = np.sqrt(XJ2145**2 + YJ2145**2 + ZJ2145**2)


##########

print('##EPTA##')
print('DB1937  ',rhodm(DB1937))
print('DJ0751  ',rhodm(DJ0751))
print('DJ1012  ',rhodm(DJ1012))
print('DJ1022  ',rhodm(DJ1022))
print('DJ1024  ',rhodm(DJ1024))
print('DJ1600  ',rhodm(DJ1600))
print('DJ1643  ',rhodm(DJ1643))
print('DJ1713  ',rhodm(DJ1713))
print('DJ1730  ',rhodm(DJ1730))
print('DJ1744  ',rhodm(DJ1744))
print('DJ1911  ',rhodm(DJ1911))
print('DJ2145  ',rhodm(DJ2145))
# Out:
# DEARTH   8121.999999999999
# DJ0437   0.3463948977656373
# DCRAB    0.20927730557530533
# DJ0613   0.28387870638978246
# DJ0711   0.35091920081576333
# DJ1022   0.3252861067476686
# DJ1024   0.31352873888533245
# DJ1045   0.3595981059770824
# DJ1600   0.5688790004305728
# DJ1603   0.5902081779987364
# DJ1643   0.4988853669233608
# DJ1713   0.44606629185604146
# DJ1730   0.39203090154742315
# DJ1732   0.5322655209805199
# DJ1744   0.38306155898317024
# DJ1824   1.9018748295324428
# DJ1857   0.47940863529560496
# DJ1909   0.45393682405496993
# DJ1939   0.44379267703382935
# DJ2124   0.37684092772587047
# DJ2129   0.546950349435551
# DJ2145   0.37876040909034625
# DJ1745   828.0672653389632
# DgcJ1744 66.208325428012
# ##EPTA##
# DB1937   0.3463948977656373
# DJ0751   0.2881974268735673
# DJ1012   0.29712490148560805
# DJ1022   0.313465798997369
# DJ1024   0.32418628309211434
# DJ1600   0.485041423539659
# DJ1643   0.4111964200191182
# DJ1713   0.42695373223259525
# ...
